# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import math
import glob
import time
from datetime import date
from typing import Tuple, Union

import numpy as np
import pandas as pd
import pydicom
from tqdm import tqdm_notebook as tqdm
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K

from sklearn.model_selection import ShuffleSplit, StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import MultiLabelBinarizer
from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit
# Out:
# 2024-12-12 00:00:36.884960: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733961636.905538  138556 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733961636.911922  138556 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#--------------------- for working with directory ----------------------------
ROOT_DATA_PATH='/workspace/datasets'
DATASET_PATH=f'{ROOT_DATA_PATH}/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection'

TRAIN_DATA_PATH=f'{DATASET_PATH}/stage_2_train'
TEST_DATA_PATH=f'{DATASET_PATH}/stage_2_test'
TRAIN_METADATA_PATH=f'{DATASET_PATH}/stage_2_train.csv'
TEST_METADATA_PATH=f'{DATASET_PATH}/stage_2_sample_submission.csv'
TRAIN_METADATA_SEQ_PATH=f'{ROOT_DATA_PATH}/rsna-intracranial-sequence-metadata/train_metadata_noidx.csv'
TEST_METADATA_SEQ_PATH=f'{ROOT_DATA_PATH}/rsna-intracranial-sequence-metadata/test_metadata_noidx.csv'

SEED = 666

# %%
#seeding
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
class ImagePreparationUtil:
    @staticmethod
    def correct_dcm(dcm: pydicom.FileDataset):
        x = dcm.pixel_array
        x = x + 1000
        px_mode = 4096
        x[x >= px_mode] = x[x >= px_mode] - px_mode
        dcm.PixelData = x.tobytes()
        dcm.RescaleIntercept = -1000
        
    @staticmethod
    def window_image(dcm: pydicom.FileDataset, window_center: int, window_width: int):
        if (dcm.BitsStored == 12) and (dcm.PixelRepresentation == 0) and (int(dcm.RescaleIntercept) > -100):
            ImagePreparationUtil.correct_dcm(dcm)
        
        # Pixel to Hounsfield Unit (HU)
        # HU=(Pixel Value×RescaleSlope)+RescaleIntercept
        img = dcm.pixel_array
        img = img * dcm.RescaleSlope + dcm.RescaleIntercept 
        img_min = window_center - window_width // 2
        img_max = window_center + window_width // 2
        img = np.clip(img, img_min, img_max)
        
        return img
    
    @staticmethod
    def get_windowed_image(dcm: pydicom.FileDataset, window: Union['brain', 'subdural', 'soft'] = 'brain') -> np.ndarray: # type: ignore
        im = None
        match window:
            case 'brain':
                brain_img = ImagePreparationUtil.window_image(dcm, 40, 80)
                brain_img = (brain_img - 0) / 80
                im = brain_img
            case 'subdural':
                subdural_img = ImagePreparationUtil.window_image(dcm, 80, 200)
                subdural_img = (subdural_img - (-20)) / 200
                im = subdural_img
            case 'soft':
                soft_img = ImagePreparationUtil.window_image(dcm, 40, 380)
                soft_img = (soft_img - (-150)) / 380
                im = soft_img
            case _:
                raise ValueError('invalid window argument')
        
        return im
    
    @staticmethod
    def bsb_window(dcm):
        brain_img = ImagePreparationUtil.get_windowed_image(dcm, window='brain')
        subdural_img = ImagePreparationUtil.get_windowed_image(dcm, window='subdural')
        soft_img = ImagePreparationUtil.get_windowed_image(dcm, window='soft')

        bsb_img = np.array([brain_img, subdural_img, soft_img]).transpose(1,2,0)

        return bsb_img
    
    @staticmethod
    def read(path, resize: Tuple[int, int]):
        img = None
        try:
            dcm = pydicom.dcmread(path)
            img = ImagePreparationUtil.bsb_window(dcm)
        except Exception as e:
            print('\nWarning:', e.__class__.__name__, f'for {path} Replacing with zeros image')
            img = np.zeros((*tuple(resize[:2]), 3), dtype=np.float32)
        
        if resize is not None:
            img = cv2.resize(img, resize[:2], interpolation=cv2.INTER_LINEAR)
            
        return img.astype(np.float32)

# %%
class MetadataLoader:
    def __init__(self, train_metadata_path = TRAIN_METADATA_PATH, test_metadata_path = TEST_METADATA_PATH, lazy_load = True):
      self.train_metadata_path = train_metadata_path
      self.test_metadata_path = test_metadata_path
      self._lazy_load = lazy_load
      self._train_df = None
      self._test_df = None
      
      if not self._lazy_load:
        self._load_trainset()
        self._load_testset()
        
    def _read(self, is_read_train_metadata = True):
        csv_file = self.train_metadata_path
        if not is_read_train_metadata:
            csv_file = self.test_metadata_path
            
        df = pd.read_csv(csv_file)
        
        df["Image"] = df["ID"].str.slice(stop=12)
        df["Diagnosis"] = df["ID"].str.slice(start=13)
        
        if is_read_train_metadata:
            duplicates_to_remove = [
                56346, 56347, 56348, 56349,
                56350, 56351, 1171830, 1171831,
                1171832, 1171833, 1171834, 1171835,
                3705312, 3705313, 3705314, 3705315,
                3705316, 3705317, 3842478, 3842479,
                3842480, 3842481, 3842482, 3842483
            ]
            df = df.drop(index=duplicates_to_remove)
            df = df.reset_index(drop=True)
        
        df = df.loc[:, ['Label', 'Diagnosis', 'Image']]
        df = df.set_index(['Image', 'Diagnosis']).unstack(level=-1)
        
        return df
    
    def sync_with_actual_file(self):
        """
        Some files maybe didn't contain legitimate images, so we need to remove them from dataframe if any
        """
        if self._train_df is None:
            self._load_trainset()
        
        dcms = glob.glob(os.path.join(TRAIN_DATA_PATH, '*.dcm'))
        dcms = [os.path.basename(dcm)[:-4] for dcm in dcms]
        
        self._train_df = self._train_df[self._train_df.index.isin(dcms)]

    def _load_trainset(self):
        self._train_df = self._read(is_read_train_metadata=True)
    
    def _load_testset(self):
        self._test_df = self._read(is_read_train_metadata=False)
    
    def reload_set(self):
        self._load_trainset()
        self._load_testset()
    
    @property
    def train_df(self):
        if self._train_df is not None:
            return self._train_df
        self._load_trainset()
        return self._train_df
    
    @property
    def test_df(self):
        if self._test_df is not None:
            return self._test_df
        self._load_testset()
        return self._test_df

# %%
def plot_data_distribution(df, legend_suptitle):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    fig.suptitle(legend_suptitle)
    sns.countplot(data=df['Label'], x='any', hue='any',  ax=axes[0], palette='Reds')
    axes[0].set_title("Distribution of ICH Diagnoses (Positive vs Negative)")
    axes[0].set_xlabel("ICH Diagnosis (0=Negative, 1=Positive)")
    axes[0].set_ylabel('Count')
    for c in axes[0].containers:
        axes[0].bar_label(c , fmt=lambda x: f'{(x/df["Label"]["any"].count())*100:0.1f}%')

    df_label_counts = df['Label'].sum(axis=0)[1:].reset_index()
    df_label_counts.columns = ['Label', 'Count']
        
    sns.barplot(x='Label', y='Count', data=df_label_counts, hue='Label' , palette='Set2')
    axes[1].set_title('Percentage of Positive Occurrences by ICH Type')
    axes[1].set_xlabel('ICH Type')
    axes[1].set_ylabel('Positive Occurrence (%)')
    plt.setp(axes[1].get_xticklabels(), rotation=45)
    for c in axes[1].containers:
        axes[1].bar_label(c ,fmt=lambda x: f'{x/len(df.index)*100:0.01f}%')

# %%
df_loader = MetadataLoader()
df = df_loader.train_df
df
# Out:
#              Label                                                          \
# Diagnosis      any epidural intraparenchymal intraventricular subarachnoid
# Image
# ID_000012eaf     0        0                0                0            0
# ID_000039fa0     0        0                0                0            0
# ID_00005679d     0        0                0                0            0
# ID_00008ce3c     0        0                0                0            0
# ID_0000950d7     0        0                0                0            0
# ...            ...      ...              ...              ...          ...
# ID_ffff82e46     0        0                0                0            0
# ID_ffff922b9     1        0                0                1            0
# ID_ffffb670a     1        0                0                0            1
# ID_ffffcbff8     0        0                0                0            0
# ID_fffff9393     0        0                0                0            0
#
#
# Diagnosis    subdural
# Image
# ID_000012eaf        0
# ID_000039fa0        0
# ID_00005679d        0
# ID_00008ce3c        0
# ID_0000950d7        0
# ...               ...
# ID_ffff82e46        0
# ID_ffff922b9        0
# ID_ffffb670a        0
# ID_ffffcbff8        0
# ID_fffff9393        0
#
# [752803 rows x 6 columns]

# %%
plot_data_distribution(df, 'Original data distribution before undersampled')

# %%
df['Label']['any'].value_counts()
# Out:
# any
# 0    644870
# 1    107933
# Name: count, dtype: int64

# %%
num_positive_diag = df['Label'][df['Label']['any'] == 1].shape[0]
df_negative_diag_selection = df[df['Label']['any'] == 0].sample(n=int(num_positive_diag), replace=False)
df_negative_diag_selection
# Out:
#              Label                                                          \
# Diagnosis      any epidural intraparenchymal intraventricular subarachnoid
# Image
# ID_29f852fa1     0        0                0                0            0
# ID_324ad996b     0        0                0                0            0
# ID_de3f846d2     0        0                0                0            0
# ID_7ff46b6e6     0        0                0                0            0
# ID_f410172f9     0        0                0                0            0
# ...            ...      ...              ...              ...          ...
# ID_791ef7020     0        0                0                0            0
# ID_6b512e2f5     0        0                0                0            0
# ID_f0efa4b0b     0        0                0                0            0
# ID_2b883eb14     0        0                0                0            0
# ID_7668eaad8     0        0                0                0            0
#
#
# Diagnosis    subdural
# Image
# ID_29f852fa1        0
# ID_324ad996b        0
# ID_de3f846d2        0
# ID_7ff46b6e6        0
# ID_f410172f9        0
# ...               ...
# ID_791ef7020        0
# ID_6b512e2f5        0
# ID_f0efa4b0b        0
# ID_2b883eb14        0
# ID_7668eaad8        0
#
# [107933 rows x 6 columns]

# %%
df = df[(df['Label']['any'] == 1) | df.index.isin(df_negative_diag_selection.index.values)]
df = df.sample(frac=1)
df
# Out:
#              Label                                                          \
# Diagnosis      any epidural intraparenchymal intraventricular subarachnoid
# Image
# ID_d119d112e     0        0                0                0            0
# ID_15929fc09     1        0                0                0            0
# ID_3545d4f76     1        0                0                1            0
# ID_4ec645046     0        0                0                0            0
# ID_0f19fb28b     0        0                0                0            0
# ...            ...      ...              ...              ...          ...
# ID_849d33f57     1        0                0                1            1
# ID_01562df58     1        0                0                1            0
# ID_718816bca     0        0                0                0            0
# ID_7f199f5bd     1        0                0                1            0
# ID_98018c310     1        0                0                0            0
#
#
# Diagnosis    subdural
# Image
# ID_d119d112e        0
# ID_15929fc09        1
# ID_3545d4f76        0
# ID_4ec645046        0
# ID_0f19fb28b        0
# ...               ...
# ID_849d33f57        0
# ID_01562df58        0
# ID_718816bca        0
# ID_7f199f5bd        0
# ID_98018c310        1
#
# [215866 rows x 6 columns]

# %%
df['Label']['any'].value_counts()
# Out:
# any
# 0    107933
# 1    107933
# Name: count, dtype: int64

# %%
plot_data_distribution(df, 'Data distribution after negative class undersampled')

# %%
class TrainDataGenerator(keras.utils.Sequence):
    def __init__(self, img_ids, labels, img_dir, img_shape, num_classes, batch_size, under_sampling=False, shuffle_on_epoch_end=True, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.img_ids = img_ids
        self.labels = labels
        self.img_dir = img_dir
        self.img_shape = img_shape
        self.num_classes = num_classes
        self.batch_size = batch_size
        self.under_sampling = under_sampling
        self.shuffle_on_epoch_end = shuffle_on_epoch_end
        self.on_epoch_end()
    
    def __len__(self):
        return math.ceil(len(self.img_ids) / self.batch_size)

    def __getitem__(self, index):
        low = index*self.batch_size
        high = min(low + self.batch_size, len(self.img_ids))
        indices = self.indices[low:high]
        X,y = self.__data_generation(indices)

        return X,y
    
    def on_epoch_end(self):
        self.indices = np.arange(len(self.img_ids))
        
        if self.under_sampling:
            keep_prob = self.labels.iloc[:,0].map({0: 0.35, 1: 0.5})
            keep = (keep_prob > np.random.rand(len(keep_prob)))
            self.indices = self.indices[keep]
            
        if self.shuffle_on_epoch_end:
            np.random.shuffle(self.indices)

        
    def __data_generation(self, indices):
        X = np.empty((self.batch_size, *self.img_shape))
        y = np.empty((self.batch_size, self.num_classes), dtype=np.float32)
        
        for i, img_idx in enumerate(indices):
            img_id = self.img_ids[img_idx]
            img_path = f'{self.img_dir}/{img_id}.dcm'
            img = ImagePreparationUtil.read(img_path, self.img_shape[:2])
            X[i,] = img
            y[i,] = self.labels.iloc[img_idx].values
            
        return X,y

# %%
class DeepModel():
    def __init__(self, base,input_shape, batch_size, num_epochs, num_classes, learning_rate, decay_rate, decay_steps, base_name='base_model', weights='imagenet', freeze_base=False, saving_path=None, verbose=1):
        self.base = base
        self.input_shape = input_shape
        self.batch_size = batch_size
        self.num_epochs = num_epochs
        self.num_classes = num_classes
        self.learning_rate = learning_rate
        self.decay_rate = decay_rate
        self.decay_steps = decay_steps
        self.base_name = base_name
        self.weights = weights
        self.freeze_base = freeze_base
        self.saving_path = saving_path
        self.verbose = verbose
        self._build()
        self._create_saving_path_if_none()
    
    def _build(self):
        K.clear_session()
        base = self.base(include_top=False, weights=self.weights, pooling='avg', input_shape=self.input_shape)
        base.trainable = not self.freeze_base
            
        x = base.output
        # x = layers.Dense(512, activation='relu', name='hidden_layer_1')(x)
        # x = layers.Dropout(0.4)(x)
        # x = layers.Dense(512, activation='relu', name='hidden_layer_2')(x)
        # x = layers.Dropout(0.6)(x)
        # x = layers.Dense(512, activation='relu', name='hidden_layer_3')(x)
        x = layers.Dropout(0.2)(x)
        out = layers.Dense(self.num_classes, activation='sigmoid', name='dense_output')(x)
        
        self.model = keras.models.Model(inputs=base.input, outputs=out)
        
        
        self.model.compile(
            loss=keras.losses.BinaryCrossentropy(), 
            optimizer=keras.optimizers.Adam(learning_rate=self.learning_rate),
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.TruePositives(),
                keras.metrics.TrueNegatives(),
                keras.metrics.FalsePositives(),
                keras.metrics.FalseNegatives(),
                keras.metrics.Precision(),
                keras.metrics.Recall(),
                keras.metrics.AUC(name='auc_roc', curve='ROC'),
                keras.metrics.AUC(name='auc_pr', curve='PR'),
                keras.metrics.F1Score(name='f1_score'),
            ]
        )
        
    def _create_saving_path_if_none(self):
        if self.saving_path is None:
            print('saving_path is None. Automatically create path for save training utilities')
            saving_path = os.path.join('saved_model', self.base.__name__)
            os.makedirs(saving_path, exist_ok=True)
            self.saving_path = saving_path
            print(self.saving_path, 'created for saving_path')
        else:
            os.makedirs(self.saving_path, exist_ok=True)
            print('saving_path: ', self.saving_path)
            
        
    def fit(self, train_df, valid_df):
        train_data_gen = TrainDataGenerator(
            img_ids=train_df.index, 
            labels=train_df,
            img_dir=TRAIN_DATA_PATH,
            img_shape=self.input_shape,
            num_classes=self.num_classes,
            batch_size=self.batch_size,
            under_sampling=False,
            workers=128,
            use_multiprocessing=True
        )
        
        valid_data_gen = TrainDataGenerator(
            img_ids=valid_df.index, 
            labels=valid_df,
            img_dir=TRAIN_DATA_PATH,
            img_shape=self.input_shape,
            num_classes=self.num_classes,
            batch_size=self.batch_size,
            under_sampling=False,
            workers=128,
            use_multiprocessing=True
        )
        
        curr_time = int(time.time())
        callbacks = [
            keras.callbacks.ModelCheckpoint(filepath='%s/{epoch:02d}-%s.weights.h5' % (self.saving_path, curr_time), monitor='val_loss', mode='min', verbose=self.verbose, save_weights_only=True, save_best_only=True),
            keras.callbacks.LearningRateScheduler(lambda epoch: self.learning_rate * pow(self.decay_rate, math.floor(epoch / self.decay_steps)), verbose=1),
            keras.callbacks.EarlyStopping(verbose=1, restore_best_weights=True, monitor='val_loss', patience=3, mode='min'),
            keras.callbacks.CSVLogger(filename='%s/%s.csv'%(self.saving_path, f'{curr_time}-train_log'))
        ]
        
        # class_weight = generate_class_weights(train_df.to_numpy(), multi_class=False, one_hot_encoded=True)
        return self.model.fit(
            x=train_data_gen,
            validation_data=valid_data_gen,
            callbacks=callbacks,
            epochs=self.num_epochs,
            verbose=self.verbose
        )
    
    def save(self, filename, overwrite=True):
        _, ext = os.path.splitext(filename)
        if ext != '.keras':
          filename = f'{filename}.keras'
          
        p = os.path.join(self.saving_path, filename)
        self.model.save(p, overwrite=overwrite)
        print('model saved to:', p)
        
    def load_weights(self, path, *args, **kwargs):
        self.model.load_weights(path, *args, **kwargs)
        
    def load(self, path, *args, **kwargs):
        self.model = keras.models.load_model(path, *args, **kwargs)

# %%
EPOCH = 12
INPUT_SHAPE = (256, 256, 3)
BATCH_SIZE = 64
N_CLASSES = 1

# %%
# let's try for binary classification (1 = ICH presence, 0 = ICH not presence)
df = df.drop(columns=df.columns[1:], axis=1)
df
# Out:
#              Label
# Diagnosis      any
# Image
# ID_d119d112e     0
# ID_15929fc09     1
# ID_3545d4f76     1
# ID_4ec645046     0
# ID_0f19fb28b     0
# ...            ...
# ID_849d33f57     1
# ID_01562df58     1
# ID_718816bca     0
# ID_7f199f5bd     1
# ID_98018c310     1
#
# [215866 rows x 1 columns]

# %%
test_df_neg = df[df['Label']['any'] == 0].sample(n=200)
test_df_pos = df[df['Label']['any'] == 1].sample(n=200)
test_df = pd.concat([test_df_pos, test_df_neg]).sample(frac=1)

# %%
df = df.drop(test_df.index)
df.value_counts()
# Out:
# (Label, any)
# 0               107733
# 1               107733
# Name: count, dtype: int64

# %%
model = DeepModel(
    base=keras.applications.EfficientNetB4,
    weights='imagenet',
    freeze_base=False,
    input_shape=INPUT_SHAPE, 
    batch_size=BATCH_SIZE, 
    num_epochs=EPOCH,
    num_classes=N_CLASSES,
    learning_rate=0.00125, 
    decay_rate=0.5, 
    decay_steps=1,
    base_name='efficientnetb4_binary',
    saving_path='saved_model/efficientnetb4_binary'
)
# Out:
# I0000 00:00:1733962163.393008  138556 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8225 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 1g.10gb, pci bus id: 0000:07:00.0, compute capability: 8.0
# saving_path:  saved_model/efficientnetb4_binary

# %%
ss = ShuffleSplit(n_splits=5, test_size=0.2, random_state=SEED).split(df.index)
# lets go for first fold only
train_idx, valid_idx = next(ss)

# %%
hist = model.fit(df.iloc[train_idx], df.iloc[valid_idx])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 1/12
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733962294.812142  139105 service.cc:148] XLA service 0x7f59440032d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733962294.812184  139105 service.cc:156]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB MIG 1g.10gb, Compute Capability 8.0
# I0000 00:00:1733962303.166032  139105 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1733962373.234189  139105 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1114/2694 ━━━━━━━━━━━━━━━━━━━━ 18:29 702ms/step - auc_pr: 0.9149 - auc_roc: 0.9112 - binary_accuracy: 0.8310 - f1_score: 0.6678 - false_negatives: 2943.9775 - false_positives: 2416.0269 - loss: 0.3691 - precision: 0.8400 - recall: 0.8214 - true_negatives: 15415.2041 - true_positives: 14904.7920
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 713ms/step - auc_pr: 0.9354 - auc_roc: 0.9323 - binary_accuracy: 0.8565 - f1_score: 0.6670 - false_negatives: 6090.9653 - false_positives: 5012.9058 - loss: 0.3246 - precision: 0.8657 - recall: 0.8452 - true_negatives: 38121.7734 - true_positives: 37014.3594
# Epoch 1: val_loss improved from inf to 5.50526, saving model to saved_model/efficientnetb4_binary/01-1733962195.weights.h5
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2572s 889ms/step - auc_pr: 0.9354 - auc_roc: 0.9323 - binary_accuracy: 0.8565 - f1_score: 0.6670 - false_negatives: 6092.8237 - false_positives: 5014.4785 - loss: 0.3245 - precision: 0.8657 - recall: 0.8452 - true_negatives: 38136.1719 - true_positives: 37028.5039 - val_auc_pr: 0.4996 - val_auc_roc: 0.5000 - val_binary_accuracy: 0.5004 - val_f1_score: 0.6663 - val_false_negatives: 21550.0000 - val_false_positives: 0.0000e+00 - val_loss: 5.5053 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_true_negatives: 21586.0000 - val_true_positives: 0.0000e+00 - learning_rate: 0.0012
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 2/12
#  230/2694 ━━━━━━━━━━━━━━━━━━━━ 31:32 768ms/step - auc_pr: 0.9747 - auc_roc: 0.9745 - binary_accuracy: 0.9190 - f1_score: 0.6660 - false_negatives: 300.9391 - false_positives: 297.2522 - loss: 0.2047 - precision: 0.9194 - recall: 0.9183 - true_negatives: 3419.7173 - true_positives: 3374.0913
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - auc_pr: 0.9745 - auc_roc: 0.9744 - binary_accuracy: 0.9184 - f1_score: 0.6663 - false_negatives: 3647.0300 - false_positives: 3375.0435 - loss: 0.2041 - precision: 0.9208 - recall: 0.9154 - true_negatives: 39744.5508 - true_positives: 39473.3750
# Epoch 2: val_loss improved from 5.50526 to 3.47588, saving model to saved_model/efficientnetb4_binary/02-1733962195.weights.h5
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2432s 895ms/step - auc_pr: 0.9745 - auc_roc: 0.9744 - binary_accuracy: 0.9184 - f1_score: 0.6663 - false_negatives: 3648.3877 - false_positives: 3376.2576 - loss: 0.2041 - precision: 0.9208 - recall: 0.9154 - true_negatives: 39759.3125 - true_positives: 39488.0156 - val_auc_pr: 0.4996 - val_auc_roc: 0.5000 - val_binary_accuracy: 0.5007 - val_f1_score: 0.6661 - val_false_negatives: 21539.0000 - val_false_positives: 0.0000e+00 - val_loss: 3.4759 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_true_negatives: 21597.0000 - val_true_positives: 0.0000e+00 - learning_rate: 6.2500e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 3/12
# 2393/2694 ━━━━━━━━━━━━━━━━━━━━ 3:45 750ms/step - auc_pr: 0.9838 - auc_roc: 0.9839 - binary_accuracy: 0.9356 - f1_score: 0.6676 - false_negatives: 2434.4146 - false_positives: 2428.2366 - loss: 0.1613 - precision: 0.9357 - recall: 0.9358 - true_negatives: 35824.3047 - true_positives: 35921.0430
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - auc_pr: 0.9838 - auc_roc: 0.9839 - binary_accuracy: 0.9358 - f1_score: 0.6675 - false_negatives: 2734.8088 - false_positives: 2726.9180 - loss: 0.1609 - precision: 0.9359 - recall: 0.9360 - true_negatives: 40340.7344 - true_positives: 40437.5391
# Epoch 3: val_loss improved from 3.47588 to 1.38707, saving model to saved_model/efficientnetb4_binary/03-1733962195.weights.h5
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2495s 918ms/step - auc_pr: 0.9838 - auc_roc: 0.9839 - binary_accuracy: 0.9358 - f1_score: 0.6675 - false_negatives: 2735.8008 - false_positives: 2727.9023 - loss: 0.1609 - precision: 0.9359 - recall: 0.9360 - true_negatives: 40355.7500 - true_positives: 40452.5234 - val_auc_pr: 0.6958 - val_auc_roc: 0.7118 - val_binary_accuracy: 0.5295 - val_f1_score: 0.6661 - val_false_negatives: 20120.0000 - val_false_positives: 177.0000 - val_loss: 1.3871 - val_precision: 0.8892 - val_recall: 0.0659 - val_true_negatives: 21419.0000 - val_true_positives: 1420.0000 - learning_rate: 3.1250e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00015625.
# Epoch 4/12
# 1248/2694 ━━━━━━━━━━━━━━━━━━━━ 17:55 743ms/step - auc_pr: 0.9907 - auc_roc: 0.9913 - binary_accuracy: 0.9570 - f1_score: 0.6662 - false_negatives: 824.8125 - false_positives: 887.4688 - loss: 0.1164 - precision: 0.9558 - recall: 0.9583 - true_negatives: 19134.9395 - true_positives: 19120.7793
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - auc_pr: 0.9910 - auc_roc: 0.9915 - binary_accuracy: 0.9570 - f1_score: 0.6662 - false_negatives: 1767.2354 - false_positives: 1943.7758 - loss: 0.1148 - precision: 0.9553 - recall: 0.9587 - true_negatives: 41222.7461 - true_positives: 41306.2422
# Epoch 4: val_loss did not improve from 1.38707
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2431s 895ms/step - auc_pr: 0.9910 - auc_roc: 0.9915 - binary_accuracy: 0.9570 - f1_score: 0.6662 - false_negatives: 1767.8936 - false_positives: 1944.4976 - loss: 0.1148 - precision: 0.9553 - recall: 0.9587 - true_negatives: 41237.9844 - true_positives: 41321.6016 - val_auc_pr: 0.4465 - val_auc_roc: 0.4421 - val_binary_accuracy: 0.4995 - val_f1_score: 0.6662 - val_false_negatives: 6.0000 - val_false_positives: 21583.0000 - val_loss: 2.1576 - val_precision: 0.4995 - val_recall: 0.9997 - val_true_negatives: 9.0000 - val_true_positives: 21538.0000 - learning_rate: 1.5625e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 7.8125e-05.
# Epoch 5/12
# 2037/2694 ━━━━━━━━━━━━━━━━━━━━ 8:11 748ms/step - auc_pr: 0.9961 - auc_roc: 0.9963 - binary_accuracy: 0.9732 - f1_score: 0.6691 - false_negatives: 793.2558 - false_positives: 958.5228 - loss: 0.0726 - precision: 0.9706 - recall: 0.9764 - true_negatives: 31539.5059 - true_positives: 31924.7148
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - auc_pr: 0.9961 - auc_roc: 0.9963 - binary_accuracy: 0.9732 - f1_score: 0.6686 - false_negatives: 1057.7286 - false_positives: 1253.1288 - loss: 0.0726 - precision: 0.9708 - recall: 0.9761 - true_negatives: 41775.0898 - true_positives: 42154.0547
# Epoch 5: val_loss improved from 1.38707 to 0.37190, saving model to saved_model/efficientnetb4_binary/05-1733962195.weights.h5
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2481s 910ms/step - auc_pr: 0.9961 - auc_roc: 0.9963 - binary_accuracy: 0.9732 - f1_score: 0.6686 - false_negatives: 1058.1373 - false_positives: 1253.5781 - loss: 0.0726 - precision: 0.9708 - recall: 0.9761 - true_negatives: 41790.6484 - true_positives: 42169.6094 - val_auc_pr: 0.9459 - val_auc_roc: 0.9466 - val_binary_accuracy: 0.8800 - val_f1_score: 0.6662 - val_false_negatives: 2282.0000 - val_false_positives: 2896.0000 - val_loss: 0.3719 - val_precision: 0.8693 - val_recall: 0.8941 - val_true_negatives: 18697.0000 - val_true_positives: 19261.0000 - learning_rate: 7.8125e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 3.90625e-05.
# Epoch 6/12
#  414/2694 ━━━━━━━━━━━━━━━━━━━━ 28:26 749ms/step - auc_pr: 0.9980 - auc_roc: 0.9982 - binary_accuracy: 0.9834 - f1_score: 0.6639 - false_negatives: 93.0217 - false_positives: 119.3237 - loss: 0.0496 - precision: 0.9816 - recall: 0.9851 - true_negatives: 6569.2295 - true_positives: 6498.4253
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - auc_pr: 0.9981 - auc_roc: 0.9983 - binary_accuracy: 0.9842 - f1_score: 0.6665 - false_negatives: 612.9647 - false_positives: 747.1140 - loss: 0.0463 - precision: 0.9826 - recall: 0.9858 - true_negatives: 42336.4609 - true_positives: 42543.4570
# Epoch 6: val_loss improved from 0.37190 to 0.36714, saving model to saved_model/efficientnetb4_binary/06-1733962195.weights.h5
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2517s 925ms/step - auc_pr: 0.9981 - auc_roc: 0.9983 - binary_accuracy: 0.9842 - f1_score: 0.6665 - false_negatives: 613.2029 - false_positives: 747.4033 - loss: 0.0463 - precision: 0.9826 - recall: 0.9858 - true_negatives: 42352.1641 - true_positives: 42559.2070 - val_auc_pr: 0.9596 - val_auc_roc: 0.9595 - val_binary_accuracy: 0.9150 - val_f1_score: 0.6660 - val_false_negatives: 2374.0000 - val_false_positives: 1294.0000 - val_loss: 0.3671 - val_precision: 0.9367 - val_recall: 0.8898 - val_true_negatives: 20307.0000 - val_true_positives: 19161.0000 - learning_rate: 3.9062e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.953125e-05.
# Epoch 7/12
#  503/2694 ━━━━━━━━━━━━━━━━━━━━ 27:26 752ms/step - auc_pr: 0.9988 - auc_roc: 0.9990 - binary_accuracy: 0.9882 - f1_score: 0.6666 - false_negatives: 88.1948 - false_positives: 107.2406 - loss: 0.0342 - precision: 0.9869 - recall: 0.9896 - true_negatives: 7992.5171 - true_positives: 7940.0479
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - auc_pr: 0.9987 - auc_roc: 0.9989 - binary_accuracy: 0.9877 - f1_score: 0.6667 - false_negatives: 480.5846 - false_positives: 584.5334 - loss: 0.0356 - precision: 0.9865 - recall: 0.9890 - true_negatives: 42514.8633 - true_positives: 42660.0195
# Epoch 7: val_loss improved from 0.36714 to 0.32084, saving model to saved_model/efficientnetb4_binary/07-1733962195.weights.h5
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2491s 914ms/step - auc_pr: 0.9987 - auc_roc: 0.9989 - binary_accuracy: 0.9877 - f1_score: 0.6667 - false_negatives: 480.7618 - false_positives: 584.7469 - loss: 0.0356 - precision: 0.9865 - recall: 0.9890 - true_negatives: 42530.6367 - true_positives: 42675.8281 - val_auc_pr: 0.9591 - val_auc_roc: 0.9648 - val_binary_accuracy: 0.9253 - val_f1_score: 0.6661 - val_false_negatives: 1755.0000 - val_false_positives: 1466.0000 - val_loss: 0.3208 - val_precision: 0.9310 - val_recall: 0.9185 - val_true_negatives: 20131.0000 - val_true_positives: 19784.0000 - learning_rate: 1.9531e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 9.765625e-06.
# Epoch 8/12
# 2308/2694 ━━━━━━━━━━━━━━━━━━━━ 4:49 751ms/step - auc_pr: 0.9988 - auc_roc: 0.9990 - binary_accuracy: 0.9900 - f1_score: 0.6659 - false_negatives: 322.0208 - false_positives: 413.6075 - loss: 0.0302 - precision: 0.9888 - recall: 0.9911 - true_negatives: 36542.8945 - true_positives: 36609.4766
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - auc_pr: 0.9988 - auc_roc: 0.9990 - binary_accuracy: 0.9900 - f1_score: 0.6661 - false_negatives: 378.1953 - false_positives: 478.4247 - loss: 0.0302 - precision: 0.9889 - recall: 0.9911 - true_negatives: 42645.3516 - true_positives: 42738.0273
# Epoch 8: val_loss did not improve from 0.32084
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2467s 906ms/step - auc_pr: 0.9988 - auc_roc: 0.9990 - binary_accuracy: 0.9900 - f1_score: 0.6661 - false_negatives: 378.3414 - false_positives: 478.5944 - loss: 0.0302 - precision: 0.9889 - recall: 0.9911 - true_negatives: 42661.1562 - true_positives: 42753.8828 - val_auc_pr: 0.9548 - val_auc_roc: 0.9620 - val_binary_accuracy: 0.9248 - val_f1_score: 0.6663 - val_false_negatives: 1687.0000 - val_false_positives: 1555.0000 - val_loss: 0.3430 - val_precision: 0.9274 - val_recall: 0.9217 - val_true_negatives: 20037.0000 - val_true_positives: 19857.0000 - learning_rate: 9.7656e-06
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.8828125e-06.
# Epoch 9/12
# 1577/2694 ━━━━━━━━━━━━━━━━━━━━ 13:52 746ms/step - auc_pr: 0.9992 - auc_roc: 0.9993 - binary_accuracy: 0.9912 - f1_score: 0.6669 - false_negatives: 203.9994 - false_positives: 247.9702 - loss: 0.0262 - precision: 0.9903 - recall: 0.9920 - true_negatives: 24925.6465 - true_positives: 25118.3848
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - auc_pr: 0.9992 - auc_roc: 0.9993 - binary_accuracy: 0.9911 - f1_score: 0.6668 - false_negatives: 352.1191 - false_positives: 424.3846 - loss: 0.0264 - precision: 0.9903 - recall: 0.9919 - true_negatives: 42652.9023 - true_positives: 42810.5938
# Epoch 9: val_loss did not improve from 0.32084
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2466s 905ms/step - auc_pr: 0.9992 - auc_roc: 0.9993 - binary_accuracy: 0.9911 - f1_score: 0.6668 - false_negatives: 352.2545 - false_positives: 424.5466 - loss: 0.0264 - precision: 0.9903 - recall: 0.9919 - true_negatives: 42668.7344 - true_positives: 42826.4414 - val_auc_pr: 0.9543 - val_auc_roc: 0.9621 - val_binary_accuracy: 0.9256 - val_f1_score: 0.6662 - val_false_negatives: 1698.0000 - val_false_positives: 1511.0000 - val_loss: 0.3482 - val_precision: 0.9292 - val_recall: 0.9212 - val_true_negatives: 20082.0000 - val_true_positives: 19845.0000 - learning_rate: 4.8828e-06
#
# Epoch 10: LearningRateScheduler setting learning rate to 2.44140625e-06.
# Epoch 10/12
# 2446/2694 ━━━━━━━━━━━━━━━━━━━━ 3:06 751ms/step - auc_pr: 0.9990 - auc_roc: 0.9993 - binary_accuracy: 0.9916 - f1_score: 0.6649 - false_negatives: 290.7249 - false_positives: 374.2142 - loss: 0.0249 - precision: 0.9903 - recall: 0.9928 - true_negatives: 38862.3203 - true_positives: 38776.7422
# Warning: ValueError for /workspace/datasets/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train/ID_6431af929.dcm Replacing with zeros image
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - auc_pr: 0.9990 - auc_roc: 0.9993 - binary_accuracy: 0.9916 - f1_score: 0.6651 - false_negatives: 321.5542 - false_positives: 412.1630 - loss: 0.0249 - precision: 0.9903 - recall: 0.9928 - true_negatives: 42780.2500 - true_positives: 42726.0352
# Epoch 10: val_loss did not improve from 0.32084
# 2694/2694 ━━━━━━━━━━━━━━━━━━━━ 2503s 918ms/step - auc_pr: 0.9990 - auc_roc: 0.9993 - binary_accuracy: 0.9916 - f1_score: 0.6651 - false_negatives: 321.6779 - false_positives: 412.3158 - loss: 0.0249 - precision: 0.9903 - recall: 0.9928 - true_negatives: 42796.0469 - true_positives: 42741.9336 - val_auc_pr: 0.9534 - val_auc_roc: 0.9613 - val_binary_accuracy: 0.9261 - val_f1_score: 0.6661 - val_false_negatives: 1703.0000 - val_false_positives: 1485.0000 - val_loss: 0.3537 - val_precision: 0.9304 - val_recall: 0.9209 - val_true_negatives: 20112.0000 - val_true_positives: 19836.0000 - learning_rate: 2.4414e-06
#
# Epoch 11: LearningRateScheduler setting learning rate to 1.220703125e-06.
# Epoch 11/12
#    1/2694 ━━━━━━━━━━━━━━━━━━━━ 22:22:47 30s/step - auc_pr: 1.0000 - auc_roc: 1.0000 - binary_accuracy: 1.0000 - f1_score: 0.6383 - false_negatives: 0.0000e+00 - false_positives: 0.0000e+00 - loss: 0.0123 - precision: 1.0000 - recall: 1.0000 - true_negatives: 34.0000 - true_positives: 30.0000

# %%
model.save('final_efficientnetb4_binary.keras')
